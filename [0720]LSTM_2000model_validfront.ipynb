# %% [markdown]
# <a href="https://colab.research.google.com/github/hye0-n0/KRX_stock_prediction/blob/main/%5B0720%5DLSTM_2000model_validfront.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import os
import datetime
from concurrent.futures import ThreadPoolExecutor, as_completed
from itertools import repeat
from tqdm.auto import tqdm
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import tensorflow.keras as keras
from keras.models import Sequential
from keras.layers import Dense, LSTM, GRU, RNN, Dropout, Flatten
from keras.optimizers import SGD
from sklearn.impute import SimpleImputer
from joblib import Parallel, delayed
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from torch.utils.data import Dataset, DataLoader
from torch.autograd import Variable
import torch
import torch.nn as nn
from torchsummary import summary


import warnings
warnings.filterwarnings("ignore")

# %%
def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)

seed_everything(42) # Seed 고정

# %% [markdown]
# ## DataLoad

# %% [markdown]
# 공유드라이브는 mounting이 힘들기 때문에 </br>공유함에 있는 데이터 파일 open의 shortcut을 nyDrive에 만들면 됩니다

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df_i = pd.read_csv('/content/drive/MyDrive/open/train.csv')
df_i
# Out:
#               일자     종목코드     종목명      거래량     시가     고가     저가     종가
# 0       20210601  A060310      3S   166690   2890   2970   2885   2920
# 1       20210601  A095570  AJ네트웍스    63836   5860   5940   5750   5780
# 2       20210601  A006840   AK홀딩스   103691  35500  35600  34150  34400
# 3       20210601  A054620     APS   462544  14600  14950  13800  14950
# 4       20210601  A265520   AP시스템   131987  29150  29150  28800  29050
# ...          ...      ...     ...      ...    ...    ...    ...    ...
# 987995  20230530  A189980  흥국에프엔비   272284   3005   3035   2955   2980
# 987996  20230530  A000540    흥국화재    50218   3250   3255   3195   3215
# 987997  20230530  A003280    흥아해운   130664   1344   1395   1340   1370
# 987998  20230530  A037440      희림   141932   9170   9260   9170   9200
# 987999  20230530  A238490      힘스  2611843   6410   8220   6300   8220
#
# [988000 rows x 8 columns]

# %%
# 그냥 불러와서 사용하는 것도 GOOD choice
df = pd.read_csv('/content/drive/MyDrive/busy_kids/dacon_krx/data/stock_data_with_interest_rate.csv', dtype={'StockCode': str})
df
# Out:
#                Date StockCode   Open   High    Low  Close   Volume    Change  \
# 0        2020-05-29    000020  10900  12150  10850  11550  4470917  0.069444
# 1        2020-06-01    000020  11750  11900  11450  11600  1547269  0.004329
# 2        2020-06-02    000020  11600  11800  10950  11750  1171851  0.012931
# 3        2020-06-03    000020  12100  12100  11450  11600  1193172 -0.012766
# 4        2020-06-04    000020  11850  11850  11250  11350   975698 -0.021552
# ...             ...       ...    ...    ...    ...    ...      ...       ...
# 1473725  2023-05-23    383800   8390   8390   8310   8330   150364 -0.003589
# 1473726  2023-05-24    383800   8310   8340   8280   8300   122457 -0.003601
# 1473727  2023-05-25    383800   8300   8310   8270   8310    84241  0.001205
# 1473728  2023-05-26    383800   8300   8310   8270   8280   126681 -0.003610
# 1473729  2023-05-30    383800   8300   8300   8270   8290    70489  0.001208
#
#           금리
# 0        0.5
# 1        0.5
# 2        0.5
# 3        0.5
# 4        0.5
# ...      ...
# 1473725  3.5
# 1473726  3.5
# 1473727  3.5
# 1473728  3.5
# 1473729  3.5
#
# [1473730 rows x 9 columns]

# %% [markdown]
# ##(참고용)Data Windows
# * 예측 시점 하루 -> 15일 예측
# * target에 따라 두가지 버전

# %%
def get_target_for_single_stock(data):
    df = data.copy()
    df['target'] = df['Close'].shift(-15).fillna(method='ffill')  # NaN 값을 먼저 채웁니다.
    df['target'] = df['target'].astype(int)/1000  # 소수점을 제거합니다.

    return df

def get_target_for_all_stocks(data):
    # 데이터 프레임을 종목별로 분리합니다.
    grouped_data = data.groupby('StockCode')

    # 각 종목별로 `get_target_for_single_stock` 함수를 적용합니다.
    dfs_with_target = [get_target_for_single_stock(group) for _, group in grouped_data]

    # 처리된 데이터 프레임들을 하나로 합칩니다.
    combined_data = pd.concat(dfs_with_target, ignore_index=True)
    return combined_data

# %%
data_with_target = get_target_for_all_stocks(df)

data_with_target
# Out:
#                Date StockCode   Open   High    Low  Close   Volume    Change  \
# 0        2020-05-29    000020  10900  12150  10850  11550  4470917  0.069444
# 1        2020-06-01    000020  11750  11900  11450  11600  1547269  0.004329
# 2        2020-06-02    000020  11600  11800  10950  11750  1171851  0.012931
# 3        2020-06-03    000020  12100  12100  11450  11600  1193172 -0.012766
# 4        2020-06-04    000020  11850  11850  11250  11350   975698 -0.021552
# ...             ...       ...    ...    ...    ...    ...      ...       ...
# 1473725  2023-05-23    383800   8390   8390   8310   8330   150364 -0.003589
# 1473726  2023-05-24    383800   8310   8340   8280   8300   122457 -0.003601
# 1473727  2023-05-25    383800   8300   8310   8270   8310    84241  0.001205
# 1473728  2023-05-26    383800   8300   8310   8270   8280   126681 -0.003610
# 1473729  2023-05-30    383800   8300   8300   8270   8290    70489  0.001208
#
#           금리  target
# 0        0.5   15.70
# 1        0.5   16.00
# 2        0.5   16.85
# 3        0.5   16.90
# 4        0.5   17.50
# ...      ...     ...
# 1473725  3.5    8.29
# 1473726  3.5    8.29
# 1473727  3.5    8.29
# 1473728  3.5    8.29
# 1473729  3.5    8.29
#
# [1473730 rows x 10 columns]

# %%
df_for_scale = data_with_target.copy()

# 우선, 스케일링을 진행할 열만 선택합니다.
columns_to_scale = ['Open', 'High', 'Low', 'Close', 'Volume']
data_to_scale = df[columns_to_scale]

# 스케일링을 진행합니다.
scaler = MinMaxScaler()
scaled_data = scaler.fit_transform(data_to_scale)


# 칼럼을 스케일링하고 원래 데이터프레임에서 대체
scaled_columns = scaler.fit_transform(df_for_scale[columns_to_scale])  # 스케일링된 칼럼 얻기
df_for_scale[columns_to_scale] = scaled_columns  # 스케일링된 칼럼으로 대체

df_for_scale
# Out:
#                Date StockCode      Open      High       Low     Close  \
# 0        2020-05-29    000020  0.006158  0.006811  0.006179  0.006446
# 1        2020-06-01    000020  0.006638  0.006670  0.006521  0.006474
# 2        2020-06-02    000020  0.006554  0.006614  0.006236  0.006559
# 3        2020-06-03    000020  0.006836  0.006783  0.006521  0.006474
# 4        2020-06-04    000020  0.006695  0.006642  0.006407  0.006333
# ...             ...       ...       ...       ...       ...       ...
# 1473725  2023-05-23    383800  0.004740  0.004703  0.004732  0.004626
# 1473726  2023-05-24    383800  0.004695  0.004675  0.004715  0.004609
# 1473727  2023-05-25    383800  0.004689  0.004658  0.004710  0.004615
# 1473728  2023-05-26    383800  0.004689  0.004658  0.004710  0.004598
# 1473729  2023-05-30    383800  0.004689  0.004652  0.004710  0.004604
#
#            Volume    Change   금리  target
# 0        0.003720  0.069444  0.5   15.70
# 1        0.001287  0.004329  0.5   16.00
# 2        0.000975  0.012931  0.5   16.85
# 3        0.000993 -0.012766  0.5   16.90
# 4        0.000812 -0.021552  0.5   17.50
# ...           ...       ...  ...     ...
# 1473725  0.000125 -0.003589  3.5    8.29
# 1473726  0.000102 -0.003601  3.5    8.29
# 1473727  0.000070  0.001205  3.5    8.29
# 1473728  0.000105 -0.003610  3.5    8.29
# 1473729  0.000059  0.001208  3.5    8.29
#
# [1473730 rows x 10 columns]

# %%
df_for_scale['Date'] = pd.to_datetime(df_for_scale['Date'], format='%Y-%m-%d')
# valid:train = 2:8 = 145:582(일) => 2020-12-24 기준으로 나눔
# test: '2023-05-09', '2023-05-30'(15day) -> '2023-06-'
valid_df_for_scale = df_for_scale[df_for_scale['Date'].between('2020-05-29', '2020-12-24')]
valid_df_for_scale
# Out:
#               Date StockCode      Open      High       Low     Close  \
# 0       2020-05-29    000020  0.006158  0.006811  0.006179  0.006446
# 1       2020-06-01    000020  0.006638  0.006670  0.006521  0.006474
# 2       2020-06-02    000020  0.006554  0.006614  0.006236  0.006559
# 3       2020-06-03    000020  0.006836  0.006783  0.006521  0.006474
# 4       2020-06-04    000020  0.006695  0.006642  0.006407  0.006333
# ...            ...       ...       ...       ...       ...       ...
# 1468767 2020-12-22    365590  0.001101  0.001106  0.001107  0.001029
# 1468768 2020-12-23    365590  0.001109  0.001117  0.001113  0.001037
# 1468769 2020-12-24    365590  0.001118  0.001117  0.001124  0.001037
# 1469950 2020-12-23    369370  0.001840  0.001930  0.001855  0.001788
# 1469951 2020-12-24    369370  0.001877  0.001862  0.001868  0.001788
#
#            Volume    Change   금리  target
# 0        0.003720  0.069444  0.5  15.700
# 1        0.001287  0.004329  0.5  16.000
# 2        0.000975  0.012931  0.5  16.850
# 3        0.000993 -0.012766  0.5  16.900
# 4        0.000812 -0.021552  0.5  17.500
# ...           ...       ...  ...     ...
# 1468767  0.000083  0.007696  0.5   1.983
# 1468768  0.000042  0.007128  0.5   1.978
# 1468769  0.000012  0.000000  0.5   1.978
# 1469950  0.000476       NaN  0.5   3.346
# 1469951  0.000028  0.000000  0.5   3.346
#
# [279766 rows x 10 columns]

# %%
train_df_for_scale = df_for_scale[df_for_scale['Date'].between('2020-12-25', '2023-05-08')]
train_df_for_scale
# Out:
#               Date StockCode      Open      High       Low     Close  \
# 145     2020-12-28    000020  0.011299  0.011239  0.010592  0.010457
# 146     2020-12-29    000020  0.010593  0.010874  0.010678  0.010740
# 147     2020-12-30    000020  0.010791  0.011099  0.010706  0.011022
# 148     2021-01-04    000020  0.011158  0.011155  0.010735  0.010712
# 149     2021-01-05    000020  0.010734  0.010930  0.010621  0.010881
# ...            ...       ...       ...       ...       ...       ...
# 1473710 2023-04-28    383800  0.004842  0.004809  0.004841  0.004734
# 1473711 2023-05-02    383800  0.004819  0.004804  0.004852  0.004745
# 1473712 2023-05-03    383800  0.004825  0.004832  0.004852  0.004756
# 1473713 2023-05-04    383800  0.004836  0.004832  0.004875  0.004773
# 1473714 2023-05-08    383800  0.004859  0.004877  0.004897  0.004807
#
#            Volume    Change   금리  target
# 145      0.001011 -0.067500  0.5   16.90
# 146      0.000392  0.026810  0.5   16.70
# 147      0.000519  0.026110  0.5   16.40
# 148      0.000598 -0.027990  0.5   17.00
# 149      0.000550  0.015707  0.5   16.70
# ...           ...       ...  ...     ...
# 1473710  0.000113 -0.004673  3.5    8.33
# 1473711  0.000056  0.002347  3.5    8.30
# 1473712  0.000110  0.002342  3.5    8.31
# 1473713  0.000059  0.003505  3.5    8.28
# 1473714  0.000136  0.006985  3.5    8.29
#
# [1163964 rows x 10 columns]

# %%
pred_df_for_scale = df_for_scale[df_for_scale['Date'].between('2023-05-09', '2023-05-30')]
pred_df_for_scale
# Out:
#               Date StockCode      Open      High       Low     Close  \
# 728     2023-05-09    000020  0.004859  0.004882  0.004852  0.004785
# 729     2023-05-10    000020  0.004870  0.004849  0.004863  0.004779
# 730     2023-05-11    000020  0.004859  0.004843  0.004841  0.004722
# 731     2023-05-12    000020  0.004802  0.004787  0.004767  0.004700
# 732     2023-05-15    000020  0.004751  0.004759  0.004755  0.004694
# ...            ...       ...       ...       ...       ...       ...
# 1473725 2023-05-23    383800  0.004740  0.004703  0.004732  0.004626
# 1473726 2023-05-24    383800  0.004695  0.004675  0.004715  0.004609
# 1473727 2023-05-25    383800  0.004689  0.004658  0.004710  0.004615
# 1473728 2023-05-26    383800  0.004689  0.004658  0.004710  0.004598
# 1473729 2023-05-30    383800  0.004689  0.004652  0.004710  0.004604
#
#            Volume    Change   금리  target
# 728      0.000065  0.003497  3.5    9.70
# 729      0.000022 -0.001161  3.5    9.70
# 730      0.000045 -0.011628  3.5    9.70
# 731      0.000042 -0.004706  3.5    9.70
# 732      0.000029 -0.001182  3.5    9.70
# ...           ...       ...  ...     ...
# 1473725  0.000125 -0.003589  3.5    8.29
# 1473726  0.000102 -0.003601  3.5    8.29
# 1473727  0.000070  0.001205  3.5    8.29
# 1473728  0.000105 -0.003610  3.5    8.29
# 1473729  0.000059  0.001208  3.5    8.29
#
# [30000 rows x 10 columns]

# %%
def window_dataset(data, time_steps=20, for_periods=1):
    grouped_data = data.groupby('StockCode')  # 데이터 프레임을 종목별로 분리합니다.
    all_stock_data = []

    for stock_code, sample in tqdm(grouped_data):
        # 데이터 변환
        ts_data = sample.values
        ts_data_len = len(ts_data)
        start_index = sample.columns.to_list().index('Open')
        end_index = sample.columns.to_list().index('금리') + 1
        close_index = sample.columns.to_list().index('target')  # 종가: target -> Close

        # 입력 데이터와 타겟 데이터 생성
        inout_seq = []
        X_data = []
        y_data = []
        for i in range(0, ts_data_len - time_steps - for_periods + 1):
            X_data.append(ts_data[i : i+time_steps, start_index:end_index].astype(np.float32))
            y_data.append(ts_data[i+time_steps : i+time_steps+for_periods, close_index].astype(np.float32))

            inout_seq.append((ts_data[i : i+time_steps, start_index:end_index].astype(np.float32), ts_data[i+time_steps : i+time_steps+for_periods, close_index].astype(np.float32)))

        X_data, y_data = np.array(X_data), np.array(y_data)
        all_stock_data.append((stock_code, X_data, y_data, inout_seq))

    return all_stock_data

# %%
result = window_dataset(train_df_for_scale)
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]

# %%
print(len(result[0][3]))
# Out:
# 563

# %%
print(len(result))
result[0][1].shape[2]
# Out:
# 2000
# 7

# %% [markdown]
# ##Model Define, Train and Inference

# %% [markdown]
# ###(참고용) LSTM

# %%
device = 'cuda' if torch.cuda.is_available() else 'cpu'
torch.manual_seed(1)
if device == 'cuda':
    torch.cuda.manual_seed_all(1)

# %%
# Define the RNN model
class myLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, num_layers):
        super(myLSTM, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.lstm = nn.LSTM(input_size, hidden_size, num_layers, batch_first=True, bias = True, dropout = 0.25)
        self.fc1 = nn.Linear(hidden_size, 64)
        self.fc = nn.Linear(64, 1)
        self.tanh = nn.Tanh()
        self.dropout = nn.Dropout(0.25)

    def forward(self, x):
        h0 = torch.zeros(self.num_layers, x.shape[0], self.hidden_size).to(device)
        c0 = torch.zeros(self.num_layers, x.shape[0], self.hidden_size).to(device)
        output, (hn, cn) = self.lstm(x, (h0, c0))
        h_out = hn.view(-1, self.hidden_size) # h_out을 출력으로 사용한다.
        out = self.fc1(h_out)
        out = self.tanh(out)
        out = self.dropout(out)
        out = self.fc(out)
        return out

# %%
# Hyperparameters
input_size = result[0][1].shape[2]
hidden_size = 128
num_layers = 1
learning_rate = 0.005
batch_size = 128
num_epochs = 1000
patience = 10
verbose = 20

# %%
def train_and_predict(result, pred, batch_size, learning_rate, hidden_size, num_layers, num_epochs, patience, input_size=7, verbose=1, device='cuda'):


    trained_models = {}
    predictions = []

    for stock_data in tqdm(result):
        stock_code, X_data, y_data, inout_seq = stock_data

        # Preparing the dataset
        class TrainDataset(Dataset):
          def __init__(self, X_data, y_data):
            self.X_data = X_data
            self.y_data = y_data

          def __len__(self):
            return len(self.y_data)

          def __getitem__(self, idx):
            return self.X_data[idx], self.y_data[idx]
        train_data = TrainDataset(X_data, y_data)
        train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=False)

        #predict data 5.08~5.30
        pred_df = pred_df_for_scale[pred_df_for_scale['StockCode'] == stock_code]
        pred_df = pred_df.values
        X_pred = [pred_df[:, 2:-1]]
        X_pred = Variable(torch.Tensor(X_pred))  # ~5/30까지 15일

        #model
        model = myLSTM(input_size, hidden_size, num_layers).to(device)
        criterion = nn.MSELoss()
        optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)
        optimizer.zero_grad()

        train_hist = np.zeros(num_epochs)
        print(f"Training for stock {stock_code}")

        for epoch in range(num_epochs):
            avg_cost = 0
            total_batch = len(train_loader)

            for inputs, labels in train_loader:
                inputs = inputs.to(device)
                labels = labels.to(device)
                outputs = model(inputs)
                loss = criterion(outputs.float(), labels.float())
                optimizer.zero_grad()
                loss.backward()
                optimizer.step()
                avg_cost += loss / total_batch

            train_hist[epoch] = avg_cost
            if epoch % verbose == 0:
                print('Epoch:', '%04d' % (epoch), 'train loss :', '{:.4f}'.format(avg_cost))

            if (epoch % patience == 0) & (epoch != 0):
                if train_hist[epoch - patience] < train_hist[epoch]:
                    print('\nEarly Stopping')
                    break

        print(f"Finished training for stock {stock_code}")
        trained_models[stock_code] = model.eval()

        # 예측 값 계산
        prediction = model(torch.tensor(X_pred).float().to(device)).item()
        predictions.append((stock_code, prediction))

        # 모델 제거
        del model
        del trained_models[stock_code]

    # 결과 표시
    prediction_df = pd.DataFrame(predictions, columns=["StockCode", "final_return"])
    print(prediction_df)
    return prediction_df

# 함수 호출 예제
prediction_result = train_and_predict(result, pred_df_for_scale, batch_size=256, learning_rate=0.5, hidden_size=15, num_layers=1, num_epochs=100, patience=10, input_size=7, verbose=20, device='cuda')
# Out:
#   0%|          | 0/2000 [00:00<?, ?it/s]
# Streaming output truncated to the last 5000 lines.
# Epoch: 0040 train loss : 74.2237
#
# Early Stopping
# Finished training for stock 092230
# Training for stock 092300
# Epoch: 0000 train loss : 35.0885
# Epoch: 0020 train loss : 0.7049
#
# Early Stopping
# Finished training for stock 092300
# Training for stock 092440
# Epoch: 0000 train loss : 39.5277
# Epoch: 0020 train loss : 1.0647
# Epoch: 0040 train loss : 0.7357
#
# Early Stopping
# Finished training for stock 092440
# Training for stock 092460
# Epoch: 0000 train loss : 43.1635
# Epoch: 0020 train loss : 1.3733
# Epoch: 0040 train loss : 0.8358
#
# Early Stopping
# Finished training for stock 092460
# Training for stock 092730
# Epoch: 0000 train loss : 418.4457
# Epoch: 0020 train loss : 41.4005
#
# Early Stopping
# Finished training for stock 092730
# Training for stock 092780
# Epoch: 0000 train loss : 42.2951
# Epoch: 0020 train loss : 1.9169
#
# Early Stopping
# Finished training for stock 092780
# Training for stock 092870
# Epoch: 0000 train loss : 98.2053
# Epoch: 0020 train loss : 8.1192
#
# Early Stopping
# Finished training for stock 092870
# Training for stock 093050
# Epoch: 0000 train loss : 173.9639
# Epoch: 0020 train loss : 4.4852
# Epoch: 0040 train loss : 3.2821
# Epoch: 0060 train loss : 3.3447
#
# Early Stopping
# Finished training for stock 093050
# Training for stock 093190
# Epoch: 0000 train loss : 43.3141
# Epoch: 0020 train loss : 0.7844
#
# Early Stopping
# Finished training for stock 093190
# Training for stock 093230
# Epoch: 0000 train loss : 39.8600
# Epoch: 0020 train loss : 2.9888
#
# Early Stopping
# Finished training for stock 093230
# Training for stock 093240
# Epoch: 0000 train loss : 51.9242
# Epoch: 0020 train loss : 3.4592
#
# Early Stopping
# Finished training for stock 093240
# Training for stock 093320
# Epoch: 0000 train loss : 2762.1821
# Epoch: 0020 train loss : 78.1999
#
# Early Stopping
# Finished training for stock 093320
# Training for stock 093370
# Epoch: 0000 train loss : 148.9149
# Epoch: 0020 train loss : 17.1927
# Epoch: 0040 train loss : 16.8872
#
# Early Stopping
# Finished training for stock 093370
# Training for stock 093520
# Epoch: 0000 train loss : 45.8583
# Epoch: 0020 train loss : 5.6562
#
# Early Stopping
# Finished training for stock 093520
# Training for stock 093640
# Epoch: 0000 train loss : 19.8494
# Epoch: 0020 train loss : 9.3851
#
# Early Stopping
# Finished training for stock 093640
# Training for stock 093920
# Epoch: 0000 train loss : 55.8704
# Epoch: 0020 train loss : 0.8293
# Epoch: 0040 train loss : 0.7497
#
# Early Stopping
# Finished training for stock 093920
# Training for stock 094170
# Epoch: 0000 train loss : 50.3685
# Epoch: 0020 train loss : 2.2790
# Epoch: 0040 train loss : 2.3685
#
# Early Stopping
# Finished training for stock 094170
# Training for stock 094280
# Epoch: 0000 train loss : 255.3400
# Epoch: 0020 train loss : 16.7752
# Epoch: 0040 train loss : 16.0793
#
# Early Stopping
# Finished training for stock 094280
# Training for stock 094360
# Epoch: 0000 train loss : 262.9117
# Epoch: 0020 train loss : 16.2732
# Epoch: 0040 train loss : 16.7936
#
# Early Stopping
# Finished training for stock 094360
# Training for stock 094480
# Epoch: 0000 train loss : 63.5126
# Epoch: 0020 train loss : 5.5780
#
# Early Stopping
# Finished training for stock 094480
# Training for stock 094820
# Epoch: 0000 train loss : 104.2977
# Epoch: 0020 train loss : 20.5582
# Epoch: 0040 train loss : 19.7911
#
# Early Stopping
# Finished training for stock 094820
# Training for stock 094840
# Epoch: 0000 train loss : 58.7411
# Epoch: 0020 train loss : 3.7383
# Epoch: 0040 train loss : 3.6959
#
# Early Stopping
# Finished training for stock 094840
# Training for stock 094850
# Epoch: 0000 train loss : 99.9484
# Epoch: 0020 train loss : 6.4954
#
# Early Stopping
# Finished training for stock 094850
# Training for stock 094860
# Epoch: 0000 train loss : 34.3096
# Epoch: 0020 train loss : 0.4677
# Epoch: 0040 train loss : 0.2411
#
# Early Stopping
# Finished training for stock 094860
# Training for stock 094940
# Epoch: 0000 train loss : 71.2414
# Epoch: 0020 train loss : 5.4346
# Epoch: 0040 train loss : 4.7690
#
# Early Stopping
# Finished training for stock 094940
# Training for stock 094970
# Epoch: 0000 train loss : 46.2837
# Epoch: 0020 train loss : 0.3793
# Epoch: 0040 train loss : 0.1970
#
# Early Stopping
# Finished training for stock 094970
# Training for stock 095190
# Epoch: 0000 train loss : 41.2929
# Epoch: 0020 train loss : 1.6906
# Epoch: 0040 train loss : 1.6502
#
# Early Stopping
# Finished training for stock 095190
# Training for stock 095270
# Epoch: 0000 train loss : 43.5246
# Epoch: 0020 train loss : 2.2030
# Epoch: 0040 train loss : 2.0028
#
# Early Stopping
# Finished training for stock 095270
# Training for stock 095340
# Epoch: 0000 train loss : 684.4603
# Epoch: 0020 train loss : 57.0079
#
# Early Stopping
# Finished training for stock 095340
# Training for stock 095500
# Epoch: 0000 train loss : 120.6063
# Epoch: 0020 train loss : 106.2671
#
# Early Stopping
# Finished training for stock 095500
# Training for stock 095570
# Epoch: 0000 train loss : 67.9280
# Epoch: 0020 train loss : 1.5217
# Epoch: 0040 train loss : 1.3556
#
# Early Stopping
# Finished training for stock 095570
# Training for stock 095610
# Epoch: 0000 train loss : 377.9360
# Epoch: 0020 train loss : 32.1344
#
# Early Stopping
# Finished training for stock 095610
# Training for stock 095660
# Epoch: 0000 train loss : 873.9041
# Epoch: 0020 train loss : 92.5299
# Epoch: 0040 train loss : 86.2999
# Epoch: 0060 train loss : 89.3134
#
# Early Stopping
# Finished training for stock 095660
# Training for stock 095700
# Epoch: 0000 train loss : 1252.9596
# Epoch: 0020 train loss : 470.6028
#
# Early Stopping
# Finished training for stock 095700
# Training for stock 095720
# Epoch: 0000 train loss : 40.5143
# Epoch: 0020 train loss : 0.3279
#
# Early Stopping
# Finished training for stock 095720
# Training for stock 095910
# Epoch: 0000 train loss : 44.7994
# Epoch: 0020 train loss : 1.3737
#
# Early Stopping
# Finished training for stock 095910
# Training for stock 096040
# Epoch: 0000 train loss : 30.9984
# Epoch: 0020 train loss : 0.0503
#
# Early Stopping
# Finished training for stock 096040
# Training for stock 096240
# Epoch: 0000 train loss : 452.7125
# Epoch: 0020 train loss : 48.9241
# Epoch: 0040 train loss : 53.9403
#
# Early Stopping
# Finished training for stock 096240
# Training for stock 096350
# Epoch: 0000 train loss : 33.9084
# Epoch: 0020 train loss : 0.0559
# Epoch: 0040 train loss : 0.0288
# Epoch: 0060 train loss : 0.0279
#
# Early Stopping
# Finished training for stock 096350
# Training for stock 096530
# Epoch: 0000 train loss : 1831.3981
# Epoch: 0020 train loss : 458.1748
#
# Early Stopping
# Finished training for stock 096530
# Training for stock 096610
# Epoch: 0000 train loss : 155.0272
# Epoch: 0020 train loss : 60.6281
# Epoch: 0040 train loss : 58.0234
#
# Early Stopping
# Finished training for stock 096610
# Training for stock 096630
# Epoch: 0000 train loss : 53.3628
# Epoch: 0020 train loss : 0.4941
# Epoch: 0040 train loss : 0.2999
#
# Early Stopping
# Finished training for stock 096630
# Training for stock 096640
# Epoch: 0000 train loss : 29.1156
# Epoch: 0020 train loss : 0.4732
# Epoch: 0040 train loss : 0.4865
#
# Early Stopping
# Finished training for stock 096640
# Training for stock 096690
# Epoch: 0000 train loss : 43.9318
# Epoch: 0020 train loss : 0.2606
# Epoch: 0040 train loss : 0.1090
#
# Early Stopping
# Finished training for stock 096690
# Training for stock 096760
# Epoch: 0000 train loss : 43.9982
# Epoch: 0020 train loss : 0.2810
#
# Early Stopping
# Finished training for stock 096760
# Training for stock 096770
# Epoch: 0000 train loss : 40559.5859
# Epoch: 0020 train loss : 2048.2334
# Epoch: 0040 train loss : 1753.4397
#
# Early Stopping
# Finished training for stock 096770
# Training for stock 097230
# Epoch: 0000 train loss : 35.5953
# Epoch: 0020 train loss : 5.3193
#
# Early Stopping
# Finished training for stock 097230
# Training for stock 097520
# Epoch: 0000 train loss : 1005.7832
# Epoch: 0020 train loss : 101.7907
# Epoch: 0040 train loss : 94.4795
#
# Early Stopping
# Finished training for stock 097520
# Training for stock 097780
# Epoch: 0000 train loss : 52.3916
# Epoch: 0020 train loss : 3.5662
#
# Early Stopping
# Finished training for stock 097780
# Training for stock 097800
# Epoch: 0000 train loss : 38.3230
# Epoch: 0020 train loss : 0.4052
# Epoch: 0040 train loss : 0.3151
#
# Early Stopping
# Finished training for stock 097800
# Training for stock 097870
# Epoch: 0000 train loss : 71.1377
# Epoch: 0020 train loss : 4.2246
# Epoch: 0040 train loss : 4.0368
#
# Early Stopping
# Finished training for stock 097870
# Training for stock 097950
# Epoch: 0000 train loss : 136873.4688
# Epoch: 0020 train loss : 3850.1638
# Epoch: 0040 train loss : 3443.5342
#
# Early Stopping
# Finished training for stock 097950
# Training for stock 098120
# Epoch: 0000 train loss : 58.0930
# Epoch: 0020 train loss : 5.8827
#
# Early Stopping
# Finished training for stock 098120
# Training for stock 098460
# Epoch: 0000 train loss : 205.5916
# Epoch: 0020 train loss : 25.9002
# Epoch: 0040 train loss : 22.5241
# Epoch: 0060 train loss : 25.1062
#
# Early Stopping
# Finished training for stock 098460
# Training for stock 099190
# Epoch: 0000 train loss : 211.7944
# Epoch: 0020 train loss : 4.1375
#
# Early Stopping
# Finished training for stock 099190
# Training for stock 099220
# Epoch: 0000 train loss : 30.4829
# Epoch: 0020 train loss : 0.1874
#
# Early Stopping
# Finished training for stock 099220
# Training for stock 099320
# Epoch: 0000 train loss : 1570.5830
# Epoch: 0020 train loss : 104.3425
#
# Early Stopping
# Finished training for stock 099320
# Training for stock 099440
# Epoch: 0000 train loss : 33.9808
# Epoch: 0020 train loss : 0.3156
# Epoch: 0040 train loss : 0.2150
#
# Early Stopping
# Finished training for stock 099440
# Training for stock 099520
# Epoch: 0000 train loss : 3.1520
# Epoch: 0020 train loss : 0.1436
# Epoch: 0040 train loss : 0.0530
# Epoch: 0060 train loss : 0.0528
#
# Early Stopping
# Finished training for stock 099520
# Training for stock 099750
# Epoch: 0000 train loss : 726.1763
# Epoch: 0020 train loss : 72.9800
#
# Early Stopping
# Finished training for stock 099750
# Training for stock 100030
# Epoch: 0000 train loss : 246.5146
# Epoch: 0020 train loss : 9.9476
#
# Early Stopping
# Finished training for stock 100030
# Training for stock 100090
# Epoch: 0000 train loss : 268.9207
# Epoch: 0020 train loss : 7.6018
# Epoch: 0040 train loss : 7.7493
#
# Early Stopping
# Finished training for stock 100090
# Training for stock 100120
# Epoch: 0000 train loss : 880.2741
# Epoch: 0020 train loss : 30.8034
# Epoch: 0040 train loss : 29.1318
#
# Early Stopping
# Finished training for stock 100120
# Training for stock 100130
# Epoch: 0000 train loss : 47.6884
# Epoch: 0020 train loss : 1.3402
# Epoch: 0040 train loss : 1.1043
#
# Early Stopping
# Finished training for stock 100130
# Training for stock 100220
# Epoch: 0000 train loss : 58.6294
# Epoch: 0020 train loss : 5.3338
#
# Early Stopping
# Finished training for stock 100220
# Training for stock 100250
# Epoch: 0000 train loss : 44.2658
# Epoch: 0020 train loss : 0.1904
# Epoch: 0040 train loss : 0.1261
#
# Early Stopping
# Finished training for stock 100250
# Training for stock 100590
# Epoch: 0000 train loss : 45.2736
# Epoch: 0020 train loss : 3.3151
# Epoch: 0040 train loss : 3.6809
#
# Early Stopping
# Finished training for stock 100590
# Training for stock 100660
# Epoch: 0000 train loss : 44.2877
# Epoch: 0020 train loss : 0.8404
#
# Early Stopping
# Finished training for stock 100660
# Training for stock 100700
# Epoch: 0000 train loss : 52.1360
# Epoch: 0020 train loss : 1.3464
#
# Early Stopping
# Finished training for stock 100700
# Training for stock 100790
# Epoch: 0000 train loss : 58.3834
# Epoch: 0020 train loss : 3.4770
#
# Early Stopping
# Finished training for stock 100790
# Training for stock 100840
# Epoch: 0000 train loss : 202.0075
# Epoch: 0020 train loss : 7.7139
# Epoch: 0040 train loss : 7.0973
#
# Early Stopping
# Finished training for stock 100840
# Training for stock 101140
# Epoch: 0000 train loss : 29.1877
# Epoch: 0020 train loss : 2.6247
#
# Early Stopping
# Finished training for stock 101140
# Training for stock 101160
# Epoch: 0000 train loss : 418.3264
# Epoch: 0020 train loss : 11.6386
#
# Early Stopping
# Finished training for stock 101160
# Training for stock 101170
# Epoch: 0000 train loss : 33.2513
# Epoch: 0020 train loss : 4.2669
# Epoch: 0040 train loss : 4.0138
#
# Early Stopping
# Finished training for stock 101170
# Training for stock 101240
# Epoch: 0000 train loss : 50.0728
# Epoch: 0020 train loss : 0.9454
#
# Early Stopping
# Finished training for stock 101240
# Training for stock 101330
# Epoch: 0000 train loss : 24.6622
# Epoch: 0020 train loss : 0.7004
#
# Early Stopping
# Finished training for stock 101330
# Training for stock 101360
# Epoch: 0000 train loss : 666.9108
# Epoch: 0020 train loss : 62.5137
#
# Early Stopping
# Finished training for stock 101360
# Training for stock 101390
# Epoch: 0000 train loss : 67.2134
# Epoch: 0020 train loss : 17.1482
# Epoch: 0040 train loss : 16.9579
#
# Early Stopping
# Finished training for stock 101390
# Training for stock 101490
# Epoch: 0000 train loss : 873.3391
# Epoch: 0020 train loss : 95.0928
# Epoch: 0040 train loss : 88.3693
#
# Early Stopping
# Finished training for stock 101490
# Training for stock 101530
# Epoch: 0000 train loss : 65.9615
# Epoch: 0020 train loss : 2.7182
#
# Early Stopping
# Finished training for stock 101530
# Training for stock 101670
# Epoch: 0000 train loss : 280.6904
#
# Early Stopping
# Finished training for stock 101670
# Training for stock 101730
# Epoch: 0000 train loss : 253.2346
# Epoch: 0020 train loss : 82.8474
# Epoch: 0040 train loss : 83.2364
#
# Early Stopping
# Finished training for stock 101730
# Training for stock 101930
# Epoch: 0000 train loss : 98.2240
# Epoch: 0020 train loss : 6.8893
#
# Early Stopping
# Finished training for stock 101930
# Training for stock 102120
# Epoch: 0000 train loss : 121.9663
# Epoch: 0020 train loss : 6.7502
# Epoch: 0040 train loss : 5.8788
#
# Early Stopping
# Finished training for stock 102120
# Training for stock 102260
# Epoch: 0000 train loss : 36.0174
# Epoch: 0020 train loss : 0.4801
#
# Early Stopping
# Finished training for stock 102260
# Training for stock 102280
# Epoch: 0000 train loss : 27.3084
# Epoch: 0020 train loss : 0.2288
# Epoch: 0040 train loss : 0.1075
#
# Early Stopping
# Finished training for stock 102280
# Training for stock 102460
# Epoch: 0000 train loss : 706.0725
# Epoch: 0020 train loss : 185.5268
# Epoch: 0040 train loss : 175.4329
#
# Early Stopping
# Finished training for stock 102460
# Training for stock 102710
# Epoch: 0000 train loss : 726.9225
# Epoch: 0020 train loss : 59.6279
# Epoch: 0040 train loss : 56.0276
# Epoch: 0060 train loss : 51.7132
#
# Early Stopping
# Finished training for stock 102710
# Training for stock 102940
# Epoch: 0000 train loss : 862.8444
# Epoch: 0020 train loss : 36.6920
# Epoch: 0040 train loss : 34.0432
# Epoch: 0060 train loss : 34.1845
#
# Early Stopping
# Finished training for stock 102940
# Training for stock 103140
# Epoch: 0000 train loss : 786.2606
# Epoch: 0020 train loss : 41.3950
# Epoch: 0040 train loss : 45.8071
#
# Early Stopping
# Finished training for stock 103140
# Training for stock 103590
# Epoch: 0000 train loss : 55.7840
# Epoch: 0020 train loss : 2.3144
# Epoch: 0040 train loss : 2.2117
#
# Early Stopping
# Finished training for stock 103590
# Training for stock 103840
# Epoch: 0000 train loss : 39.9813
# Epoch: 0020 train loss : 2.2413
#
# Early Stopping
# Finished training for stock 103840
# Training for stock 104040
# Epoch: 0000 train loss : 30.5580
# Epoch: 0020 train loss : 0.2667
#
# Early Stopping
# Finished training for stock 104040
# Training for stock 104200
# Epoch: 0000 train loss : 80.7094
# Epoch: 0020 train loss : 13.5965
#
# Early Stopping
# Finished training for stock 104200
# Training for stock 104460
# Epoch: 0000 train loss : 1305.8328
# Epoch: 0020 train loss : 84.7770
# Epoch: 0040 train loss : 89.4980
#
# Early Stopping
# Finished training for stock 104460
# Training for stock 104480
# Epoch: 0000 train loss : 54.5256
# Epoch: 0020 train loss : 3.1688
#
# Early Stopping
# Finished training for stock 104480
# Training for stock 104540
# Epoch: 0000 train loss : 105.7671
# Epoch: 0020 train loss : 10.8604
# Epoch: 0040 train loss : 10.0576
# Epoch: 0060 train loss : 9.7881
#
# Early Stopping
# Finished training for stock 104540
# Training for stock 104620
# Epoch: 0000 train loss : 97.6371
# Epoch: 0020 train loss : 13.0862
# Epoch: 0040 train loss : 14.1491
#
# Early Stopping
# Finished training for stock 104620
# Training for stock 104700
# Epoch: 0000 train loss : 70.5114
# Epoch: 0020 train loss : 2.8522
#
# Early Stopping
# Finished training for stock 104700
# Training for stock 104830
# Epoch: 0000 train loss : 852.8882
# Epoch: 0020 train loss : 27.7658
# Epoch: 0040 train loss : 28.9367
#
# Early Stopping
# Finished training for stock 104830
# Training for stock 105330
# Epoch: 0000 train loss : 71.7841
# Epoch: 0020 train loss : 5.3677
#
# Early Stopping
# Finished training for stock 105330
# Training for stock 105550
# Epoch: 0000 train loss : 57.6653
# Epoch: 0020 train loss : 1.1306
# Epoch: 0040 train loss : 1.1808
#
# Early Stopping
# Finished training for stock 105550
# Training for stock 105560
# Epoch: 0000 train loss : 2365.3606
# Epoch: 0020 train loss : 47.2621
#
# Early Stopping
# Finished training for stock 105560
# Training for stock 105630
# Epoch: 0000 train loss : 248.4776
# Epoch: 0020 train loss : 17.8302
# Epoch: 0040 train loss : 17.9590
#
# Early Stopping
# Finished training for stock 105630
# Training for stock 105740
# Epoch: 0000 train loss : 80.6199
# Epoch: 0020 train loss : 2.4133
# Epoch: 0040 train loss : 1.8204
#
# Early Stopping
# Finished training for stock 105740
# Training for stock 105840
# Epoch: 0000 train loss : 53.3512
# Epoch: 0020 train loss : 5.1222
# Epoch: 0040 train loss : 5.1888
#
# Early Stopping
# Finished training for stock 105840
# Training for stock 106080
# Epoch: 0000 train loss : 53.6400
# Epoch: 0020 train loss : 10.1525
#
# Early Stopping
# Finished training for stock 106080
# Training for stock 106190
# Epoch: 0000 train loss : 137.7599
# Epoch: 0020 train loss : 8.4054
#
# Early Stopping
# Finished training for stock 106190
# Training for stock 107590
# Epoch: 0000 train loss : 13789.7490
# Epoch: 0020 train loss : 473.6514
#
# Early Stopping
# Finished training for stock 107590
# Training for stock 108230
# Epoch: 0000 train loss : 66.8926
# Epoch: 0020 train loss : 4.5220
# Epoch: 0040 train loss : 4.1759
# Epoch: 0060 train loss : 4.4571
#
# Early Stopping
# Finished training for stock 108230
# Training for stock 108320
# Epoch: 0000 train loss : 10144.3125
# Epoch: 0020 train loss : 446.7342
#
# Early Stopping
# Finished training for stock 108320
# Training for stock 108380
# Epoch: 0000 train loss : 165.5551
# Epoch: 0020 train loss : 9.4861
#
# Early Stopping
# Finished training for stock 108380
# Training for stock 108490
# Epoch: 0000 train loss : 499.6292
# Epoch: 0020 train loss : 83.5446
#
# Early Stopping
# Finished training for stock 108490
# Training for stock 108670
# Epoch: 0000 train loss : 2907.1123
# Epoch: 0020 train loss : 502.8371
#
# Early Stopping
# Finished training for stock 108670
# Training for stock 108860
# Epoch: 0000 train loss : 106.1699
# Epoch: 0020 train loss : 89.2932
# Epoch: 0040 train loss : 85.4735
#
# Early Stopping
# Finished training for stock 108860
# Training for stock 109070
# Epoch: 0000 train loss : 34.7256
# Epoch: 0020 train loss : 0.1664
# Epoch: 0040 train loss : 0.0465
# Epoch: 0060 train loss : 0.0382
#
# Early Stopping
# Finished training for stock 109070
# Training for stock 109080
# Epoch: 0000 train loss : 166.2161
# Epoch: 0020 train loss : 24.1657
# Epoch: 0040 train loss : 24.4278
#
# Early Stopping
# Finished training for stock 109080
# Training for stock 109610
# Epoch: 0000 train loss : 14.9729
# Epoch: 0020 train loss : 0.2142
#
# Early Stopping
# Finished training for stock 109610
# Training for stock 109740
# Epoch: 0000 train loss : 63.2100
# Epoch: 0020 train loss : 3.0989
# Epoch: 0040 train loss : 2.4698
#
# Early Stopping
# Finished training for stock 109740
# Training for stock 109820
# Epoch: 0000 train loss : 85.9248
# Epoch: 0020 train loss : 15.8788
#
# Early Stopping
# Finished training for stock 109820
# Training for stock 109860
# Epoch: 0000 train loss : 175.9628
# Epoch: 0020 train loss : 76.1467
#
# Early Stopping
# Finished training for stock 109860
# Training for stock 109960
# Epoch: 0000 train loss : 35.9118
# Epoch: 0020 train loss : 0.3264
# Epoch: 0040 train loss : 0.3106
#
# Early Stopping
# Finished training for stock 109960
# Training for stock 110790
# Epoch: 0000 train loss : 875.5957
# Epoch: 0020 train loss : 104.5637
#
# Early Stopping
# Finished training for stock 110790
# Training for stock 110990
# Epoch: 0000 train loss : 60.3859
# Epoch: 0020 train loss : 4.3411
#
# Early Stopping
# Finished training for stock 110990
# Training for stock 111110
# Epoch: 0000 train loss : 88.3322
# Epoch: 0020 train loss : 6.8124
#
# Early Stopping
# Finished training for stock 111110
# Training for stock 111710
# Epoch: 0000 train loss : 62.1057
# Epoch: 0020 train loss : 2.7825
# Epoch: 0040 train loss : 2.4184
#
# Early Stopping
# Finished training for stock 111710
# Training for stock 111770
# Epoch: 0000 train loss : 1505.8223
# Epoch: 0020 train loss : 24.4112
# Epoch: 0040 train loss : 24.0794
#
# Early Stopping
# Finished training for stock 111770
# Training for stock 112040
# Epoch: 0000 train loss : 5371.5273
# Epoch: 0020 train loss : 1644.9114
# Epoch: 0040 train loss : 1651.1776
#
# Early Stopping
# Finished training for stock 112040
# Training for stock 112610
# Epoch: 0000 train loss : 3963.1018
# Epoch: 0020 train loss : 139.2304
# Epoch: 0040 train loss : 137.8198
#
# Early Stopping
# Finished training for stock 112610
# Training for stock 113810
# Epoch: 0000 train loss : 34.7195
# Epoch: 0020 train loss : 0.2387
# Epoch: 0040 train loss : 0.1417
#
# Early Stopping
# Finished training for stock 113810
# Training for stock 114090
# Epoch: 0000 train loss : 127.0087
# Epoch: 0020 train loss : 8.2883
#
# Early Stopping
# Finished training for stock 114090
# Training for stock 114190
# Epoch: 0000 train loss : 104.6774
#
# Early Stopping
# Finished training for stock 114190
# Training for stock 114450
# Epoch: 0000 train loss : 64.5746
# Epoch: 0020 train loss : 6.9872
#
# Early Stopping
# Finished training for stock 114450
# Training for stock 114630
# Epoch: 0000 train loss : 28.1310
# Epoch: 0020 train loss : 0.0688
#
# Early Stopping
# Finished training for stock 114630
# Training for stock 114810
# Epoch: 0000 train loss : 64.0924
# Epoch: 0020 train loss : 2.3788
# Epoch: 0040 train loss : 2.1134
#
# Early Stopping
# Finished training for stock 114810
# Training for stock 115160
# Epoch: 0000 train loss : 43.5474
# Epoch: 0020 train loss : 0.3215
#
# Early Stopping
# Finished training for stock 115160
# Training for stock 115180
# Epoch: 0000 train loss : 180.1556
# Epoch: 0020 train loss : 25.7771
# Epoch: 0040 train loss : 22.6465
#
# Early Stopping
# Finished training for stock 115180
# Training for stock 115310
# Epoch: 0000 train loss : 308.7773
# Epoch: 0020 train loss : 21.5674
#
# Early Stopping
# Finished training for stock 115310
# Training for stock 115390
# Epoch: 0000 train loss : 88.7336
# Epoch: 0020 train loss : 14.2936
#
# Early Stopping
# Finished training for stock 115390
# Training for stock 115440
# Epoch: 0000 train loss : 59.1907
# Epoch: 0020 train loss : 1.0883
# Epoch: 0040 train loss : 0.8647
#
# Early Stopping
# Finished training for stock 115440
# Training for stock 115450
# Epoch: 0000 train loss : 54.6021
# Epoch: 0020 train loss : 0.9903
#
# Early Stopping
# Finished training for stock 115450
# Training for stock 115480
# Epoch: 0000 train loss : 33.9177
# Epoch: 0020 train loss : 0.1638
# Epoch: 0040 train loss : 0.0346
# Epoch: 0060 train loss : 0.0366
#
# Early Stopping
# Finished training for stock 115480
# Training for stock 115500
# Epoch: 0000 train loss : 42.3590
# Epoch: 0020 train loss : 4.3989
#
# Early Stopping
# Finished training for stock 115500
# Training for stock 115610
# Epoch: 0000 train loss : 43.8370
# Epoch: 0020 train loss : 0.5922
# Epoch: 0040 train loss : 0.3502
#
# Early Stopping
# Finished training for stock 115610
# Training for stock 115960
# Epoch: 0000 train loss : 315.3181
# Epoch: 0020 train loss : 32.7147
#
# Early Stopping
# Finished training for stock 115960
# Training for stock 117580
# Epoch: 0000 train loss : 64.5550
# Epoch: 0020 train loss : 7.7957
#
# Early Stopping
# Finished training for stock 117580
# Training for stock 117730
# Epoch: 0000 train loss : 42.7431
# Epoch: 0020 train loss : 13.0234
#
# Early Stopping
# Finished training for stock 117730
# Training for stock 118000
# Epoch: 0000 train loss : 42.3550
# Epoch: 0020 train loss : 0.2728
#
# Early Stopping
# Finished training for stock 118000
# Training for stock 118990
# Epoch: 0000 train loss : 50.6292
# Epoch: 0020 train loss : 25.8499
# Epoch: 0040 train loss : 23.6873
# Epoch: 0060 train loss : 23.4654
#
# Early Stopping
# Finished training for stock 118990
# Training for stock 119500
# Epoch: 0000 train loss : 36.8865
# Epoch: 0020 train loss : 0.5426
#
# Early Stopping
# Finished training for stock 119500
# Training for stock 119610
# Epoch: 0000 train loss : 703.3925
# Epoch: 0020 train loss : 24.2114
#
# Early Stopping
# Finished training for stock 119610
# Training for stock 119650
# Epoch: 0000 train loss : 44.9043
# Epoch: 0020 train loss : 3.5473
#
# Early Stopping
# Finished training for stock 119650
# Training for stock 119830
# Epoch: 0000 train loss : 59.3983
# Epoch: 0020 train loss : 1.8439
#
# Early Stopping
# Finished training for stock 119830
# Training for stock 119850
# Epoch: 0000 train loss : 41.1170
# Epoch: 0020 train loss : 1.1457
# Epoch: 0040 train loss : 0.8094
#
# Early Stopping
# Finished training for stock 119850
# Training for stock 119860
# Epoch: 0000 train loss : 414.7154
# Epoch: 0020 train loss : 61.3499
# Epoch: 0040 train loss : 58.6152
#
# Early Stopping
# Finished training for stock 119860
# Training for stock 120030
# Epoch: 0000 train loss : 12197.4580
# Epoch: 0020 train loss : 437.6094
# Epoch: 0040 train loss : 395.0415
# Epoch: 0060 train loss : 356.8313
#
# Early Stopping
# Finished training for stock 120030
# Training for stock 120110
# Epoch: 0000 train loss : 3193.5737
# Epoch: 0020 train loss : 255.9387
#
# Early Stopping
# Finished training for stock 120110
# Training for stock 120240
# Epoch: 0000 train loss : 283.9857
# Epoch: 0020 train loss : 26.6944
#
# Early Stopping
# Finished training for stock 120240
# Training for stock 121440
# Epoch: 0000 train loss : 63.7908
# Epoch: 0020 train loss : 3.8155
#
# Early Stopping
# Finished training for stock 121440
# Training for stock 121600
# Epoch: 0000 train loss : 8282.8320
# Epoch: 0020 train loss : 2268.8572
#
# Early Stopping
# Finished training for stock 121600
# Training for stock 121800
# Epoch: 0000 train loss : 165.0412
# Epoch: 0020 train loss : 46.1217
# Epoch: 0040 train loss : 45.0547
#
# Early Stopping
# Finished training for stock 121800
# Training for stock 121850
# Epoch: 0000 train loss : 38.1342
# Epoch: 0020 train loss : 1.2755
# Epoch: 0040 train loss : 1.1246
#
# Early Stopping
# Finished training for stock 121850
# Training for stock 122310
# Epoch: 0000 train loss : 69.2759
# Epoch: 0020 train loss : 1.7091
#
# Early Stopping
# Finished training for stock 122310
# Training for stock 122350
# Epoch: 0000 train loss : 33.1863
# Epoch: 0020 train loss : 1.3458
# Epoch: 0040 train loss : 0.9473
#
# Early Stopping
# Finished training for stock 122350
# Training for stock 122450
# Epoch: 0000 train loss : 85.2230
# Epoch: 0020 train loss : 10.0465
#
# Early Stopping
# Finished training for stock 122450
# Training for stock 122640
# Epoch: 0000 train loss : 80.0866
# Epoch: 0020 train loss : 7.5388
#
# Early Stopping
# Finished training for stock 122640
# Training for stock 122690
# Epoch: 0000 train loss : 34.0282
# Epoch: 0020 train loss : 0.7695
# Epoch: 0040 train loss : 0.5873
#
# Early Stopping
# Finished training for stock 122690
# Training for stock 122870
# Epoch: 0000 train loss : 2812.9524
# Epoch: 0020 train loss : 153.9216
#
# Early Stopping
# Finished training for stock 122870
# Training for stock 122900
# Epoch: 0000 train loss : 76.0004
# Epoch: 0020 train loss : 1.1149
# Epoch: 0040 train loss : 1.2248
#
# Early Stopping
# Finished training for stock 122900
# Training for stock 122990
# Epoch: 0000 train loss : 94.1637
# Epoch: 0020 train loss : 7.5152
#
# Early Stopping
# Finished training for stock 122990
# Training for stock 123010
# Epoch: 0000 train loss : 42.1274
# Epoch: 0020 train loss : 3.4412
#
# Early Stopping
# Finished training for stock 123010
# Training for stock 123040
# Epoch: 0000 train loss : 44.9973
# Epoch: 0020 train loss : 1.7262
# Epoch: 0040 train loss : 1.7818
#
# Early Stopping
# Finished training for stock 123040
# Training for stock 123410
# Epoch: 0000 train loss : 37.7403
# Epoch: 0020 train loss : 0.5297
# Epoch: 0040 train loss : 0.3016
#
# Early Stopping
# Finished training for stock 123410
# Training for stock 123420
# Epoch: 0000 train loss : 321.5284
# Epoch: 0020 train loss : 42.4408
#
# Early Stopping
# Finished training for stock 123420
# Training for stock 123570
# Epoch: 0000 train loss : 54.0670
# Epoch: 0020 train loss : 2.7833
# Epoch: 0040 train loss : 2.7841
#
# Early Stopping
# Finished training for stock 123570
# Training for stock 123690
# Epoch: 0000 train loss : 69.1994
# Epoch: 0020 train loss : 5.0386
# Epoch: 0040 train loss : 5.1768
#
# Early Stopping
# Finished training for stock 123690
# Training for stock 123700
# Epoch: 0000 train loss : 44.0041
# Epoch: 0020 train loss : 0.6740
# Epoch: 0040 train loss : 0.6066
#
# Early Stopping
# Finished training for stock 123700
# Training for stock 123750
# Epoch: 0000 train loss : 38.5350
# Epoch: 0020 train loss : 0.8772
# Epoch: 0040 train loss : 0.6877
#
# Early Stopping
# Finished training for stock 123750
# Training for stock 123860
# Epoch: 0000 train loss : 358.2144
# Epoch: 0020 train loss : 22.0084
# Epoch: 0040 train loss : 19.9799
#
# Early Stopping
# Finished training for stock 123860
# Training for stock 123890
# Epoch: 0000 train loss : 35.5276
# Epoch: 0020 train loss : 1.1370
# Epoch: 0040 train loss : 0.9428
#
# Early Stopping
# Finished training for stock 123890
# Training for stock 124500
# Epoch: 0000 train loss : 35.7542
# Epoch: 0020 train loss : 0.7559
#
# Early Stopping
# Finished training for stock 124500
# Training for stock 124560
# Epoch: 0000 train loss : 41.0989
# Epoch: 0020 train loss : 1.0725
# Epoch: 0040 train loss : 0.8871
#
# Early Stopping
# Finished training for stock 124560
# Training for stock 125210
# Epoch: 0000 train loss : 113.2380
# Epoch: 0020 train loss : 7.5846
# Epoch: 0040 train loss : 7.0593
# Epoch: 0060 train loss : 7.3185
#
# Early Stopping
# Finished training for stock 125210
# Training for stock 126340
# Epoch: 0000 train loss : 1435.0839
# Epoch: 0020 train loss : 168.0663
#
# Early Stopping
# Finished training for stock 126340
# Training for stock 126560
# Epoch: 0000 train loss : 30.8337
# Epoch: 0020 train loss : 0.9700
#
# Early Stopping
# Finished training for stock 126560
# Training for stock 126600
# Epoch: 0000 train loss : 24.3053
# Epoch: 0020 train loss : 3.3563
# Epoch: 0040 train loss : 3.3677
#
# Early Stopping
# Finished training for stock 126600
# Training for stock 126640
# Epoch: 0000 train loss : 49.7915
# Epoch: 0020 train loss : 0.3236
# Epoch: 0040 train loss : 0.1108
#
# Early Stopping
# Finished training for stock 126640
# Training for stock 126700
# Epoch: 0000 train loss : 140.9954
# Epoch: 0020 train loss : 7.2728
#
# Early Stopping
# Finished training for stock 126700
# Training for stock 126880
# Epoch: 0000 train loss : 43.6924
# Epoch: 0020 train loss : 0.7474
# Epoch: 0040 train loss : 0.8553
#
# Early Stopping
# Finished training for stock 126880
# Training for stock 127120
# Epoch: 0000 train loss : 42.9632
# Epoch: 0020 train loss : 0.7637
# Epoch: 0040 train loss : 0.6908
#
# Early Stopping
# Finished training for stock 127120
# Training for stock 127710
# Epoch: 0000 train loss : 33.0317
# Epoch: 0020 train loss : 2.3983
# Epoch: 0040 train loss : 2.2435
# Epoch: 0060 train loss : 2.4197
#
# Early Stopping
# Finished training for stock 127710
# Training for stock 128540
# Epoch: 0000 train loss : 47.1916
# Epoch: 0020 train loss : 2.8399
# Epoch: 0040 train loss : 2.6984
#
# Early Stopping
# Finished training for stock 128540
# Training for stock 128660
# Epoch: 0000 train loss : 35.6502
# Epoch: 0020 train loss : 0.9053
# Epoch: 0040 train loss : 0.8141
#
# Early Stopping
# Finished training for stock 128660
# Training for stock 128820
# Epoch: 0000 train loss : 35.2335
# Epoch: 0020 train loss : 0.5576
# Epoch: 0040 train loss : 0.4964
#
# Early Stopping
# Finished training for stock 128820
# Training for stock 128940
# Epoch: 0000 train loss : 80359.9219
# Epoch: 0020 train loss : 1660.0884
#
# Early Stopping
# Finished training for stock 128940
# Training for stock 129260
# Epoch: 0000 train loss : 38.6556
# Epoch: 0020 train loss : 0.6402
#
# Early Stopping
# Finished training for stock 129260
# Training for stock 129890
# Epoch: 0000 train loss : 196.9904
# Epoch: 0020 train loss : 53.9621
#
# Early Stopping
# Finished training for stock 129890
# Training for stock 130500
# Epoch: 0000 train loss : 38.1488
# Epoch: 0020 train loss : 2.8418
#
# Early Stopping
# Finished training for stock 130500
# Training for stock 130580
# Epoch: 0000 train loss : 70.2074
# Epoch: 0020 train loss : 4.5739
# Epoch: 0040 train loss : 3.6007
#
# Early Stopping
# Finished training for stock 130580
# Training for stock 130660
# Epoch: 0000 train loss : 84.4602
# Epoch: 0020 train loss : 10.0026
#
# Early Stopping
# Finished training for stock 130660
# Training for stock 131030
# Epoch: 0000 train loss : 42.7918
# Epoch: 0020 train loss : 0.9712
#
# Early Stopping
# Finished training for stock 131030
# Training for stock 131090
# Epoch: 0000 train loss : 35.4186
# Epoch: 0020 train loss : 0.2060
# Epoch: 0040 train loss : 0.0527
#
# Early Stopping
# Finished training for stock 131090
# Training for stock 131100
# Epoch: 0000 train loss : 46.5058
# Epoch: 0020 train loss : 6.1398
# Epoch: 0040 train loss : 6.0293
#
# Early Stopping
# Finished training for stock 131100
# Training for stock 131220
# Epoch: 0000 train loss : 83.9431
# Epoch: 0020 train loss : 8.9048
#
# Early Stopping
# Finished training for stock 131220
# Training for stock 131290
# Epoch: 0000 train loss : 2485.8037
# Epoch: 0020 train loss : 242.5964
# Epoch: 0040 train loss : 244.1809
#
# Early Stopping
# Finished training for stock 131290
# Training for stock 131370
# Epoch: 0000 train loss : 42.9862
# Epoch: 0020 train loss : 5.6383
# Epoch: 0040 train loss : 6.2691
#
# Early Stopping
# Finished training for stock 131370
# Training for stock 131400
# Epoch: 0000 train loss : 25.5874
# Epoch: 0020 train loss : 6.8753
#
# Early Stopping
# Finished training for stock 131400
# Training for stock 131760
# Epoch: 0000 train loss : 32.8105
# Epoch: 0020 train loss : 0.1318
# Epoch: 0040 train loss : 0.0565
#
# Early Stopping
# Finished training for stock 131760
# Training for stock 131970
# Epoch: 0000 train loss : 1071.2208
# Epoch: 0020 train loss : 84.3507
# Epoch: 0040 train loss : 80.0618
# Epoch: 0060 train loss : 78.5683
#
# Early Stopping
# Finished training for stock 131970
# Training for stock 133750
# Epoch: 0000 train loss : 33.9408
# Epoch: 0020 train loss : 2.5553
# Epoch: 0040 train loss : 2.2336
#
# Early Stopping
# Finished training for stock 133750
# Training for stock 133820
# Epoch: 0000 train loss : 43.9504
# Epoch: 0020 train loss : 0.3537
#
# Early Stopping
# Finished training for stock 133820
# Training for stock 134380
# Epoch: 0000 train loss : 4432.6841
# Epoch: 0020 train loss : 91.7980
#
# Early Stopping
# Finished training for stock 134380
# Training for stock 134580
# Epoch: 0000 train loss : 30.3421
# Epoch: 0020 train loss : 5.5367
#
# Early Stopping
# Finished training for stock 134580
# Training for stock 134790
# Epoch: 0000 train loss : 2384.4302
# Epoch: 0020 train loss : 216.8951
# Epoch: 0040 train loss : 207.8897
#
# Early Stopping
# Finished training for stock 134790
# Training for stock 136480
# Epoch: 0000 train loss : 33.9508
# Epoch: 0020 train loss : 0.2015
# Epoch: 0040 train loss : 0.0841
#
# Early Stopping
# Finished training for stock 136480
# Training for stock 136490
# Epoch: 0000 train loss : 115.2220
# Epoch: 0020 train loss : 13.1741
#
# Early Stopping
# Finished training for stock 136490
# Training for stock 136510
# Epoch: 0000 train loss : 129.4062
# Epoch: 0020 train loss : 44.2959
#
# Early Stopping
# Finished training for stock 136510
# Training for stock 136540
# Epoch: 0000 train loss : 142.2488
# Epoch: 0020 train loss : 6.9692
# Epoch: 0040 train loss : 7.1087
#
# Early Stopping
# Finished training for stock 136540
# Training for stock 137400
# Epoch: 0000 train loss : 1521.8955
# Epoch: 0020 train loss : 130.2430
#
# Early Stopping
# Finished training for stock 137400
# Training for stock 137950
# Epoch: 0000 train loss : 59.5770
# Epoch: 0020 train loss : 2.5512
#
# Early Stopping
# Finished training for stock 137950
# Training for stock 138040
# Epoch: 0000 train loss : 796.4476
# Epoch: 0020 train loss : 121.1515
# Epoch: 0040 train loss : 116.3697
#
# Early Stopping
# Finished training for stock 138040
# Training for stock 138070
# Epoch: 0000 train loss : 42.0537
# Epoch: 0020 train loss : 1.3814
# Epoch: 0040 train loss : 1.1180
#
# Early Stopping
# Finished training for stock 138070
# Training for stock 138080
# Epoch: 0000 train loss : 610.0558
# Epoch: 0020 train loss : 116.5371
#
# Early Stopping
# Finished training for stock 138080
# Training for stock 138490
# Epoch: 0000 train loss : 52.8758
# Epoch: 0020 train loss : 6.5084
#
# Early Stopping
# Finished training for stock 138490
# Training for stock 138580
# Epoch: 0000 train loss : 73.5735
# Epoch: 0020 train loss : 6.1785
#
# Early Stopping
# Finished training for stock 138580
# Training for stock 138610
# Epoch: 0000 train loss : 451.3656
# Epoch: 0020 train loss : 73.2321
#
# Early Stopping
# Finished training for stock 138610
# Training for stock 138930
# Epoch: 0000 train loss : 70.1230
# Epoch: 0020 train loss : 1.5969
# Epoch: 0040 train loss : 1.0669
#
# Early Stopping
# Finished training for stock 138930
# Training for stock 139050
# Epoch: 0000 train loss : 26.8870
# Epoch: 0020 train loss : 0.1089
# Epoch: 0040 train loss : 0.0664
#
# Early Stopping
# Finished training for stock 139050
# Training for stock 139130
# Epoch: 0000 train loss : 77.5505
# Epoch: 0020 train loss : 2.6821
#
# Early Stopping
# Finished training for stock 139130
# Training for stock 139480
# Epoch: 0000 train loss : 14111.5840
# Epoch: 0020 train loss : 1095.7443
# Epoch: 0040 train loss : 1054.1333
#
# Early Stopping
# Finished training for stock 139480
# Training for stock 139670
# Epoch: 0000 train loss : 369.9330
# Epoch: 0020 train loss : 161.2669
# Epoch: 0040 train loss : 163.4164
#
# Early Stopping
# Finished training for stock 139670
# Training for stock 140070
# Epoch: 0000 train loss : 40.6238
# Epoch: 0020 train loss : 0.8907
#
# Early Stopping
# Finished training for stock 140070
# Training for stock 140410
# Epoch: 0000 train loss : 1136.1266
# Epoch: 0020 train loss : 349.2175
#
# Early Stopping
# Finished training for stock 140410
# Training for stock 140520
# Epoch: 0000 train loss : 28.2971
# Epoch: 0020 train loss : 0.4293
# Epoch: 0040 train loss : 0.3226
#
# Early Stopping
# Finished training for stock 140520
# Training for stock 140670
# Epoch: 0000 train loss : 106.7813
# Epoch: 0020 train loss : 8.3115
# Epoch: 0040 train loss : 8.4180
#
# Early Stopping
# Finished training for stock 140670
# Training for stock 140860
# Epoch: 0000 train loss : 14265.7402
# Epoch: 0020 train loss : 512.0550
#
# Early Stopping
# Finished training for stock 140860
# Training for stock 141000
# Epoch: 0000 train loss : 70.4846
# Epoch: 0020 train loss : 1.9988
# Epoch: 0040 train loss : 1.9742
#
# Early Stopping
# Finished training for stock 141000
# Training for stock 141080
# Epoch: 0000 train loss : 1622.8411
# Epoch: 0020 train loss : 68.2041
#
# Early Stopping
# Finished training for stock 141080
# Training for stock 142210
# Epoch: 0000 train loss : 40.4578
# Epoch: 0020 train loss : 1.1840
# Epoch: 0040 train loss : 0.8662
# Epoch: 0060 train loss : 0.9696
#
# Early Stopping
# Finished training for stock 142210
# Training for stock 142280
# Epoch: 0000 train loss : 93.3603
# Epoch: 0020 train loss : 6.9553
#
# Early Stopping
# Finished training for stock 142280
# Training for stock 142760
# Epoch: 0000 train loss : 69.0316
# Epoch: 0020 train loss : 7.2323
#
# Early Stopping
# Finished training for stock 142760
# Training for stock 143160
# Epoch: 0000 train loss : 423.9111
# Epoch: 0020 train loss : 8.2650
#
# Early Stopping
# Finished training for stock 143160
# Training for stock 143210
# Epoch: 0000 train loss : 44.9991
# Epoch: 0020 train loss : 3.5807
# Epoch: 0040 train loss : 3.1655
#
# Early Stopping
# Finished training for stock 143210
# Training for stock 143240
# Epoch: 0000 train loss : 999.8264
# Epoch: 0020 train loss : 95.4411
#
# Early Stopping
# Finished training for stock 143240
# Training for stock 143540
# Epoch: 0000 train loss : 45.0217
# Epoch: 0020 train loss : 0.7240
# Epoch: 0040 train loss : 0.4605
#
# Early Stopping
# Finished training for stock 143540
# Training for stock 144510
# Epoch: 0000 train loss : 4672.7002
# Epoch: 0020 train loss : 679.5981
# Epoch: 0040 train loss : 684.2173
#
# Early Stopping
# Finished training for stock 144510
# Training for stock 144960
# Epoch: 0000 train loss : 21.4479
# Epoch: 0020 train loss : 1.9845
# Epoch: 0040 train loss : 1.9592
#
# Early Stopping
# Finished training for stock 144960
# Training for stock 145020
# Epoch: 0000 train loss : 20763.5488
# Epoch: 0020 train loss : 1515.8813
#
# Early Stopping
# Finished training for stock 145020
# Training for stock 145210
# Epoch: 0000 train loss : 134.4787
# Epoch: 0020 train loss : 45.8424
#
# Early Stopping
# Finished training for stock 145210
# Training for stock 145720
# Epoch: 0000 train loss : 9049.6885
# Epoch: 0020 train loss : 1422.6145
# Epoch: 0040 train loss : 1316.2283
#
# Early Stopping
# Finished training for stock 145720
# Training for stock 145990
# Epoch: 0000 train loss : 2188.9983
# Epoch: 0020 train loss : 153.5536
# Epoch: 0040 train loss : 143.7189
#
# Early Stopping
# Finished training for stock 145990
# Training for stock 147760
# Epoch: 0000 train loss : 63.7776
# Epoch: 0020 train loss : 4.3302
#
# Early Stopping
# Finished training for stock 147760
# Training for stock 147830
# Epoch: 0000 train loss : 32.6951
# Epoch: 0020 train loss : 0.4066
# Epoch: 0040 train loss : 0.3922
#
# Early Stopping
# Finished training for stock 147830
# Training for stock 148150
# Epoch: 0000 train loss : 241.8408
# Epoch: 0020 train loss : 23.3000
#
# Early Stopping
# Finished training for stock 148150
# Training for stock 148250
# Epoch: 0000 train loss : 126.3784
# Epoch: 0020 train loss : 16.1673
#
# Early Stopping
# Finished training for stock 148250
# Training for stock 149950
# Epoch: 0000 train loss : 213.4129
# Epoch: 0020 train loss : 8.3820
#
# Early Stopping
# Finished training for stock 149950
# Training for stock 149980
# Epoch: 0000 train loss : 39.9023
# Epoch: 0020 train loss : 2.2743
# Epoch: 0040 train loss : 2.1398
#
# Early Stopping
# Finished training for stock 149980
# Training for stock 150840
# Epoch: 0000 train loss : 37.2738
# Epoch: 0020 train loss : 2.8286
# Epoch: 0040 train loss : 2.5747
# Epoch: 0060 train loss : 2.6278
#
# Early Stopping
# Finished training for stock 150840
# Training for stock 150900
# Epoch: 0000 train loss : 64.1969
# Epoch: 0020 train loss : 2.9623
# Epoch: 0040 train loss : 2.7777
#
# Early Stopping
# Finished training for stock 150900
# Training for stock 151860
# Epoch: 0000 train loss : 102.0274
# Epoch: 0020 train loss : 21.7996
#
# Early Stopping
# Finished training for stock 151860
# Training for stock 151910
# Epoch: 0000 train loss : 19.4441
# Epoch: 0020 train loss : 10.5217
# Epoch: 0040 train loss : 9.5192
#
# Early Stopping
# Finished training for stock 151910
# Training for stock 153460
# Epoch: 0000 train loss : 47.1287
# Epoch: 0020 train loss : 1.8148
# Epoch: 0040 train loss : 1.3400
#
# Early Stopping
# Finished training for stock 153460
# Training for stock 153490
# Epoch: 0000 train loss : 25.4326
# Epoch: 0020 train loss : 0.1501
# Epoch: 0040 train loss : 0.1829
#
# Early Stopping
# Finished training for stock 153490
# Training for stock 153710
# Epoch: 0000 train loss : 80.1155
# Epoch: 0020 train loss : 6.4437
#
# Early Stopping
# Finished training for stock 153710
# Training for stock 155650
# Epoch: 0000 train loss : 42.7431
# Epoch: 0020 train loss : 2.3948
# Epoch: 0040 train loss : 2.0042
#
# Early Stopping
# Finished training for stock 155650
# Training for stock 155660
# Epoch: 0000 train loss : 53.2645
# Epoch: 0020 train loss : 1.1288
#
# Early Stopping
# Finished training for stock 155660
# Training for stock 156100
# Epoch: 0000 train loss : 194.8506
# Epoch: 0020 train loss : 69.0240
#
# Early Stopping
# Finished training for stock 156100
# Training for stock 158430
# Epoch: 0000 train loss : 597.7424
# Epoch: 0020 train loss : 44.3137
# Epoch: 0040 train loss : 37.8178
#
# Early Stopping
# Finished training for stock 158430
# Training for stock 159580
# Epoch: 0000 train loss : 92.4483
# Epoch: 0020 train loss : 7.3271
#
# Early Stopping
# Finished training for stock 159580
# Training for stock 159910
# Epoch: 0000 train loss : 38.2549
# Epoch: 0020 train loss : 0.1261
# Epoch: 0040 train loss : 0.0346
#
# Early Stopping
# Finished training for stock 159910
# Training for stock 160550
# Epoch: 0000 train loss : 86.6644
# Epoch: 0020 train loss : 9.9976
#
# Early Stopping
# Finished training for stock 160550
# Training for stock 160600
# Epoch: 0000 train loss : 42.3997
# Epoch: 0020 train loss : 0.1524
# Epoch: 0040 train loss : 0.0266
# Epoch: 0060 train loss : 0.0206
# Epoch: 0080 train loss : 0.0122
# Finished training for stock 160600
# Training for stock 160980
# Epoch: 0000 train loss : 167.0292
# Epoch: 0020 train loss : 16.5129
#
# Early Stopping
# Finished training for stock 160980
# Training for stock 161000
# Epoch: 0000 train loss : 80.0836
# Epoch: 0020 train loss : 15.7895
# Epoch: 0040 train loss : 16.6243
#
# Early Stopping
# Finished training for stock 161000
# Training for stock 161390
# Epoch: 0000 train loss : 1047.0901
# Epoch: 0020 train loss : 52.7329
# Epoch: 0040 train loss : 48.1322
#
# Early Stopping
# Finished training for stock 161390
# Training for stock 161580
# Epoch: 0000 train loss : 72.6476
# Epoch: 0020 train loss : 4.0143
#
# Early Stopping
# Finished training for stock 161580
# Training for stock 161890
# Epoch: 0000 train loss : 1551.1337
# Epoch: 0020 train loss : 69.2025
#
# Early Stopping
# Finished training for stock 161890
# Training for stock 163560
# Epoch: 0000 train loss : 58.0456
# Epoch: 0020 train loss : 3.1502
# Epoch: 0040 train loss : 2.8826
#
# Early Stopping
# Finished training for stock 163560
# Training for stock 163730
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 163730
# Training for stock 164060
# Epoch: 0000 train loss : 51.8432
# Epoch: 0020 train loss : 0.9440
# Epoch: 0040 train loss : 0.9332
#
# Early Stopping
# Finished training for stock 164060
# Training for stock 166090
# Epoch: 0000 train loss : 1527.0178
# Epoch: 0020 train loss : 87.2927
#
# Early Stopping
# Finished training for stock 166090
# Training for stock 166480
# Epoch: 0000 train loss : 155.1517
# Epoch: 0020 train loss : 26.8197
# Epoch: 0040 train loss : 25.2034
#
# Early Stopping
# Finished training for stock 166480
# Training for stock 168330
# Epoch: 0000 train loss : 64.9934
# Epoch: 0020 train loss : 3.6074
#
# Early Stopping
# Finished training for stock 168330
# Training for stock 169330
# Epoch: 0000 train loss : 40.9725
# Epoch: 0020 train loss : 0.7387
# Epoch: 0040 train loss : 0.5821
#
# Early Stopping
# Finished training for stock 169330
# Training for stock 170030
# Epoch: 0000 train loss : 44.9605
# Epoch: 0020 train loss : 1.7742
#
# Early Stopping
# Finished training for stock 170030
# Training for stock 170790
# Epoch: 0000 train loss : 107.1997
# Epoch: 0020 train loss : 5.1717
# Epoch: 0040 train loss : 4.7089
# Epoch: 0060 train loss : 4.5862
#
# Early Stopping
# Finished training for stock 170790
# Training for stock 170900
# Epoch: 0000 train loss : 3528.7310
# Epoch: 0020 train loss : 149.5695
#
# Early Stopping
# Finished training for stock 170900
# Training for stock 170920
# Epoch: 0000 train loss : 109.0677
# Epoch: 0020 train loss : 3.3185
# Epoch: 0040 train loss : 3.4054
#
# Early Stopping
# Finished training for stock 170920
# Training for stock 171010
# Epoch: 0000 train loss : 57.0877
# Epoch: 0020 train loss : 0.8780
#
# Early Stopping
# Finished training for stock 171010
# Training for stock 171090
# Epoch: 0000 train loss : 318.5967
# Epoch: 0020 train loss : 75.0490
#
# Early Stopping
# Finished training for stock 171090
# Training for stock 171120
# Epoch: 0000 train loss : 60.8975
# Epoch: 0020 train loss : 2.0318
#
# Early Stopping
# Finished training for stock 171120
# Training for stock 173130
# Epoch: 0000 train loss : 22.4272
#
# Early Stopping
# Finished training for stock 173130
# Training for stock 173940
# Epoch: 0000 train loss : 48.9712
# Epoch: 0020 train loss : 2.7605
#
# Early Stopping
# Finished training for stock 173940
# Training for stock 174900
# Epoch: 0000 train loss : 230.7185
# Epoch: 0020 train loss : 24.4152
#
# Early Stopping
# Finished training for stock 174900
# Training for stock 175140
# Epoch: 0000 train loss : 51.5267
# Epoch: 0020 train loss : 1.3163
#
# Early Stopping
# Finished training for stock 175140
# Training for stock 175250
# Epoch: 0000 train loss : 121.0101
# Epoch: 0020 train loss : 36.9222
# Epoch: 0040 train loss : 35.1884
#
# Early Stopping
# Finished training for stock 175250
# Training for stock 175330
# Epoch: 0000 train loss : 49.7234
# Epoch: 0020 train loss : 1.1891
# Epoch: 0040 train loss : 1.0542
# Epoch: 0060 train loss : 0.9154
#
# Early Stopping
# Finished training for stock 175330
# Training for stock 177350
# ...
# Epoch: 0020 train loss : 6.7588
#
# Early Stopping
# Finished training for stock 317120
# Training for stock 317240
# Epoch: 0000 train loss : 31.9478
# Epoch: 0020 train loss : 0.1015
#
# Early Stopping
# Finished training for stock 317240
# Training for stock 317330
# Epoch: 0000 train loss : 279.7610
# Epoch: 0020 train loss : 26.3863
#
# Early Stopping
# Finished training for stock 317330
# Training for stock 317400
# Epoch: 0000 train loss : 76.0024
# Epoch: 0020 train loss : 4.1131
#
# Early Stopping
# Finished training for stock 317400
# Training for stock 317530
# Epoch: 0000 train loss : 104.7068
# Epoch: 0020 train loss : 24.0957
#
# Early Stopping
# Finished training for stock 317530
# Training for stock 317690
# Epoch: 0000 train loss : 106.8160
# Epoch: 0020 train loss : 23.3258
#
# Early Stopping
# Finished training for stock 317690
# Training for stock 317770
# Epoch: 0000 train loss : 77.7175
# Epoch: 0020 train loss : 7.8979
#
# Early Stopping
# Finished training for stock 317770
# Training for stock 317830
# Epoch: 0000 train loss : 33.7816
# Epoch: 0020 train loss : 15.7749
# Epoch: 0040 train loss : 13.9445
# Epoch: 0060 train loss : 13.7657
# Epoch: 0080 train loss : 15.1299
#
# Early Stopping
# Finished training for stock 317830
# Training for stock 317850
# Epoch: 0000 train loss : 46.4867
# Epoch: 0020 train loss : 17.9302
#
# Early Stopping
# Finished training for stock 317850
# Training for stock 317870
# Epoch: 0000 train loss : 63.7152
# Epoch: 0020 train loss : 7.3102
#
# Early Stopping
# Finished training for stock 317870
# Training for stock 318000
# Epoch: 0000 train loss : 40.0621
# Epoch: 0020 train loss : 13.0448
#
# Early Stopping
# Finished training for stock 318000
# Training for stock 318010
# Epoch: 0000 train loss : 111.0062
# Epoch: 0020 train loss : 9.7168
#
# Early Stopping
# Finished training for stock 318010
# Training for stock 318020
# Epoch: 0000 train loss : 251.1953
# Epoch: 0020 train loss : 12.1640
#
# Early Stopping
# Finished training for stock 318020
# Training for stock 318410
# Epoch: 0000 train loss : 128.8611
# Epoch: 0020 train loss : 17.5432
# Epoch: 0040 train loss : 17.6210
#
# Early Stopping
# Finished training for stock 318410
# Training for stock 319400
# Epoch: 0000 train loss : 8.6935
# Epoch: 0020 train loss : 0.9189
# Epoch: 0040 train loss : 0.8617
#
# Early Stopping
# Finished training for stock 319400
# Training for stock 319660
# Epoch: 0000 train loss : 266.4260
# Epoch: 0020 train loss : 9.6621
# Epoch: 0040 train loss : 9.9205
#
# Early Stopping
# Finished training for stock 319660
# Training for stock 320000
# Epoch: 0000 train loss : 69.4769
# Epoch: 0020 train loss : 3.1922
#
# Early Stopping
# Finished training for stock 320000
# Training for stock 321260
# Epoch: 0000 train loss : 37.2452
# Epoch: 0020 train loss : 1.0712
# Epoch: 0040 train loss : 0.7981
#
# Early Stopping
# Finished training for stock 321260
# Training for stock 321550
# Epoch: 0000 train loss : 173.0031
# Epoch: 0020 train loss : 20.0072
# Epoch: 0040 train loss : 21.7520
#
# Early Stopping
# Finished training for stock 321550
# Training for stock 322000
# Epoch: 0000 train loss : 1202.6646
# Epoch: 0020 train loss : 218.1818
# Epoch: 0040 train loss : 208.4161
#
# Early Stopping
# Finished training for stock 322000
# Training for stock 322180
# Epoch: 0000 train loss : 79.7051
# Epoch: 0020 train loss : 12.2053
#
# Early Stopping
# Finished training for stock 322180
# Training for stock 322310
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 322310
# Training for stock 322510
# Epoch: 0000 train loss : 50.9642
# Epoch: 0020 train loss : 3.5114
#
# Early Stopping
# Finished training for stock 322510
# Training for stock 322780
# Epoch: 0000 train loss : 31.8801
# Epoch: 0020 train loss : 0.2883
#
# Early Stopping
# Finished training for stock 322780
# Training for stock 323280
# Epoch: 0000 train loss : 43.2095
# Epoch: 0020 train loss : 0.3845
# Epoch: 0040 train loss : 0.3190
#
# Early Stopping
# Finished training for stock 323280
# Training for stock 323990
# Epoch: 0000 train loss : 2836.9868
# Epoch: 0020 train loss : 525.5572
#
# Early Stopping
# Finished training for stock 323990
# Training for stock 326030
# Epoch: 0000 train loss : 6067.3447
# Epoch: 0020 train loss : 511.8555
# Epoch: 0040 train loss : 483.8765
#
# Early Stopping
# Finished training for stock 326030
# Training for stock 327260
# Epoch: 0000 train loss : 106.5684
# Epoch: 0020 train loss : 3.6409
# Epoch: 0040 train loss : 3.1873
# Epoch: 0060 train loss : 3.2931
#
# Early Stopping
# Finished training for stock 327260
# Training for stock 330350
# Epoch: 0000 train loss : 82.8507
# Epoch: 0020 train loss : 8.3830
#
# Early Stopping
# Finished training for stock 330350
# Training for stock 330860
# Epoch: 0000 train loss : 1032.2668
# Epoch: 0020 train loss : 136.7578
# Epoch: 0040 train loss : 133.2927
#
# Early Stopping
# Finished training for stock 330860
# Training for stock 331520
# Epoch: 0000 train loss : 28.9941
# Epoch: 0020 train loss : 0.4659
#
# Early Stopping
# Finished training for stock 331520
# Training for stock 332290
# Epoch: 0000 train loss : 39.3028
# Epoch: 0020 train loss : 0.3798
#
# Early Stopping
# Finished training for stock 332290
# Training for stock 332370
# Epoch: 0000 train loss : 40.6526
# Epoch: 0020 train loss : 0.2923
# Epoch: 0040 train loss : 0.1583
#
# Early Stopping
# Finished training for stock 332370
# Training for stock 332570
# Epoch: 0000 train loss : 45.9060
# Epoch: 0020 train loss : 12.3597
# Epoch: 0040 train loss : 10.6282
#
# Early Stopping
# Finished training for stock 332570
# Training for stock 333430
# Epoch: 0000 train loss : 38.1199
# Epoch: 0020 train loss : 0.5014
# Epoch: 0040 train loss : 0.4611
#
# Early Stopping
# Finished training for stock 333430
# Training for stock 333620
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 333620
# Training for stock 334970
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 334970
# Training for stock 335810
# Epoch: 0000 train loss : 105.5179
# Epoch: 0020 train loss : 22.3594
#
# Early Stopping
# Finished training for stock 335810
# Training for stock 335890
# Epoch: 0000 train loss : 44.3158
# Epoch: 0020 train loss : 4.1045
#
# Early Stopping
# Finished training for stock 335890
# Training for stock 336060
# Epoch: 0000 train loss : 40.4452
# Epoch: 0020 train loss : 0.3643
#
# Early Stopping
# Finished training for stock 336060
# Training for stock 336260
# Epoch: 0000 train loss : 1182.5751
# Epoch: 0020 train loss : 74.4960
#
# Early Stopping
# Finished training for stock 336260
# Training for stock 336370
# Epoch: 0000 train loss : 2376.6023
# Epoch: 0020 train loss : 268.9844
# Epoch: 0040 train loss : 258.0020
#
# Early Stopping
# Finished training for stock 336370
# Training for stock 336570
# Epoch: 0000 train loss : 19.9687
# Epoch: 0020 train loss : 3.7669
#
# Early Stopping
# Finished training for stock 336570
# Training for stock 337930
# Epoch: 0000 train loss : 65.3810
# Epoch: 0020 train loss : 5.7509
#
# Early Stopping
# Finished training for stock 337930
# Training for stock 338220
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 338220
# Training for stock 339770
# Epoch: 0000 train loss : 176.3465
# Epoch: 0020 train loss : 23.4915
#
# Early Stopping
# Finished training for stock 339770
# Training for stock 339950
# Epoch: 0000 train loss : 44.0822
# Epoch: 0020 train loss : 1.0080
#
# Early Stopping
# Finished training for stock 339950
# Training for stock 340440
# Epoch: 0000 train loss : 41.7560
# Epoch: 0020 train loss : 0.3058
# Epoch: 0040 train loss : 0.1395
#
# Early Stopping
# Finished training for stock 340440
# Training for stock 340570
# Epoch: 0000 train loss : 1128.3818
# Epoch: 0020 train loss : 81.1342
# Epoch: 0040 train loss : 84.8833
#
# Early Stopping
# Finished training for stock 340570
# Training for stock 340930
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 340930
# Training for stock 344820
# Epoch: 0000 train loss : 2078.4084
# Epoch: 0020 train loss : 150.1671
#
# Early Stopping
# Finished training for stock 344820
# Training for stock 347700
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 347700
# Training for stock 347740
# Epoch: 0000 train loss : 32.3150
# Epoch: 0020 train loss : 1.2522
#
# Early Stopping
# Finished training for stock 347740
# Training for stock 347770
# Epoch: 0000 train loss : 226.3270
# Epoch: 0020 train loss : 39.7044
#
# Early Stopping
# Finished training for stock 347770
# Training for stock 347860
# Epoch: 0000 train loss : 290.9184
# Epoch: 0020 train loss : 62.6390
#
# Early Stopping
# Finished training for stock 347860
# Training for stock 347890
# Epoch: 0000 train loss : 66.5556
# Epoch: 0020 train loss : 1.8189
# Epoch: 0040 train loss : 1.4339
# Epoch: 0060 train loss : 1.6422
#
# Early Stopping
# Finished training for stock 347890
# Training for stock 348030
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 348030
# Training for stock 348150
# Epoch: 0000 train loss : 313.1160
# Epoch: 0020 train loss : 72.1779
#
# Early Stopping
# Finished training for stock 348150
# Training for stock 348210
# Epoch: 0000 train loss : 2670.0608
# Epoch: 0020 train loss : 82.4053
# Epoch: 0040 train loss : 84.1200
#
# Early Stopping
# Finished training for stock 348210
# Training for stock 348350
# Epoch: 0000 train loss : 191.8745
# Epoch: 0020 train loss : 22.5325
#
# Early Stopping
# Finished training for stock 348350
# Training for stock 351320
# Epoch: 0000 train loss : 34.0142
# Epoch: 0020 train loss : 0.7726
#
# Early Stopping
# Finished training for stock 351320
# Training for stock 351330
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 351330
# Training for stock 352480
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 352480
# Training for stock 352700
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 352700
# Training for stock 352770
# Epoch: 0000 train loss : 75.4727
# Epoch: 0020 train loss : 8.1146
#
# Early Stopping
# Finished training for stock 352770
# Training for stock 352820
# Epoch: 0000 train loss : 58976.9102
# Epoch: 0020 train loss : 4478.4951
# Epoch: 0040 train loss : 4512.1626
#
# Early Stopping
# Finished training for stock 352820
# Training for stock 352940
# Epoch: 0000 train loss : 78.1486
# Epoch: 0020 train loss : 10.6352
#
# Early Stopping
# Finished training for stock 352940
# Training for stock 353190
# Epoch: 0000 train loss : 44.4978
# Epoch: 0020 train loss : 0.8406
# Epoch: 0040 train loss : 0.7651
#
# Early Stopping
# Finished training for stock 353190
# Training for stock 353200
# Epoch: 0000 train loss : 306.2484
# Epoch: 0020 train loss : 25.7805
# Epoch: 0040 train loss : 25.6702
# Epoch: 0060 train loss : 25.3543
# Epoch: 0080 train loss : 26.8113
#
# Early Stopping
# Finished training for stock 353200
# Training for stock 353810
# Epoch: 0000 train loss : 58.4236
# Epoch: 0020 train loss : 1.8545
# Epoch: 0040 train loss : 2.1029
#
# Early Stopping
# Finished training for stock 353810
# Training for stock 354200
# Epoch: 0000 train loss : 144.4492
# Epoch: 0020 train loss : 30.8415
#
# Early Stopping
# Finished training for stock 354200
# Training for stock 355150
# Epoch: 0000 train loss : 35.6250
# Epoch: 0020 train loss : 0.3851
#
# Early Stopping
# Finished training for stock 355150
# Training for stock 356860
# Epoch: 0000 train loss : 227.0406
# Epoch: 0020 train loss : 6.2160
#
# Early Stopping
# Finished training for stock 356860
# Training for stock 356890
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 356890
# Training for stock 357230
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 357230
# Training for stock 357550
# Epoch: 0000 train loss : 590.0504
# Epoch: 0020 train loss : 243.6443
# Epoch: 0040 train loss : 236.3632
#
# Early Stopping
# Finished training for stock 357550
# Training for stock 357780
# Epoch: 0000 train loss : 60755.7109
# Epoch: 0020 train loss : 2236.5732
# Epoch: 0040 train loss : 2189.2986
#
# Early Stopping
# Finished training for stock 357780
# Training for stock 359090
# Epoch: 0000 train loss : 37.3802
# Epoch: 0020 train loss : 1.3785
# Epoch: 0040 train loss : 0.9804
#
# Early Stopping
# Finished training for stock 359090
# Training for stock 361390
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 361390
# Training for stock 361610
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 361610
# Training for stock 363250
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 363250
# Training for stock 363260
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 363260
# Training for stock 363280
# Epoch: 0000 train loss : 336.6086
# Epoch: 0020 train loss : 64.1612
#
# Early Stopping
# Finished training for stock 363280
# Training for stock 365590
# Epoch: 0000 train loss : 31.5435
# Epoch: 0020 train loss : 0.3383
#
# Early Stopping
# Finished training for stock 365590
# Training for stock 368770
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 368770
# Training for stock 369370
# Epoch: 0000 train loss : 28.6938
# Epoch: 0020 train loss : 1.8490
#
# Early Stopping
# Finished training for stock 369370
# Training for stock 373200
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 373200
# Training for stock 375500
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 375500
# Training for stock 378850
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 378850
# Training for stock 383220
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 383220
# Training for stock 383310
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 383310
# Training for stock 383800
# Epoch: 0000 train loss : nan
# Epoch: 0020 train loss : nan
# Epoch: 0040 train loss : nan
# Epoch: 0060 train loss : nan
# Epoch: 0080 train loss : nan
# Finished training for stock 383800
#      StockCode  final_return
# 0       000020     10.500755
# 1       000040      0.683205
# 2       000050     12.144964
# 3       000070     83.287567
# 4       000080     28.176144
# ...        ...           ...
# 1995    375500           NaN
# 1996    378850           NaN
# 1997    383220           NaN
# 1998    383310           NaN
# 1999    383800           NaN
#
# [2000 rows x 2 columns]

# %%
prediction_result.tail(500)
prediction_result.to_csv('./prediction_result.csv', index=False)

# %%
last_rows = df.groupby('StockCode').last().reset_index()
last_rows
# Out:
#      StockCode        Date    Open    High     Low   Close  Volume    Change  \
# 0       000020  2023-05-30    9960   10040    9640    9700  201361 -0.015228
# 1       000040  2023-05-30     704     707     676     680  430077 -0.028571
# 2       000050  2023-05-30   10430   10480   10350   10440    7087  0.000000
# 3       000070  2023-05-30   72900   74000   72000   72600    4051 -0.001376
# 4       000080  2023-05-30   23700   23750   22900   23000  412668 -0.019190
# ...        ...         ...     ...     ...     ...     ...     ...       ...
# 1995    375500  2023-05-30   36850   37200   36200   36750  170274  0.023677
# 1996    378850  2023-05-30    4520    4580    4350    4460   88590 -0.004464
# 1997    383220  2023-05-30  135000  135200  131100  131700  151534 -0.022272
# 1998    383310  2023-05-30   62600   62800   61200   62000  116680 -0.001610
# 1999    383800  2023-05-30    8300    8300    8270    8290   70489  0.001208
#
#        금리
# 0     3.5
# 1     3.5
# 2     3.5
# 3     3.5
# 4     3.5
# ...   ...
# 1995  3.5
# 1996  3.5
# 1997  3.5
# 1998  3.5
# 1999  3.5
#
# [2000 rows x 9 columns]

# %%
last_close_df = last_rows[['StockCode', 'Close']]
merged_df = prediction_result.merge(last_close_df, on='StockCode')
merged_df['changes'] = (merged_df['final_return'] - merged_df['Close']) / merged_df['Close']

prediction_result['changes'] = merged_df['changes']

# %%
prediction_result.head(200)
# Out:
#     StockCode  final_return   changes
# 0      000020      9.615606 -0.999009
# 1      000040      0.703073 -0.998966
# 2      000050     12.264784 -0.998825
# 3      000070     83.353607 -0.998852
# 4      000080     28.182224 -0.998775
# ..        ...           ...       ...
# 195    004540      3.208254 -0.998805
# 196    004560     14.567581 -0.999055
# 197    004590      4.969447 -0.998859
# 198    004650     11.041225 -0.998966
# 199    004690    231.933014 -0.998113
#
# [200 rows x 3 columns]

# %%
prediction_result.fillna(0, inplace=True)
prediction_result.sort_values(by='changes', ascending=False, na_position='last', inplace=True)

# %%
prediction_result
# Out:
#      StockCode  final_return   changes
# 1999    383800      0.000000  0.000000
# 1740    247660      0.000000  0.000000
# 1971    352700      0.000000  0.000000
# 1708    236810      0.000000  0.000000
# 1943    333620      0.000000  0.000000
# ...        ...           ...       ...
# 1181    086520    253.367111 -0.999536
# 1847    290690      9.985394 -0.999565
# 278     006740      8.072506 -0.999596
# 1914    317770      3.288991 -0.999657
# 1277    096610      5.294982 -0.999735
#
# [2000 rows x 3 columns]

# %%
prediction_result.reset_index(drop=True, inplace=True)
prediction_result['순위'] = range(1, 2001)
prediction_result.rename(columns={'StockCode': '종목코드'}, inplace=True)
prediction_result.drop(['final_return', 'changes'], axis=1, inplace=True)
prediction_result
# Out:
#         종목코드    순위
# 0     383800     1
# 1     247660     2
# 2     352700     3
# 3     236810     4
# 4     333620     5
# ...      ...   ...
# 1995  086520  1996
# 1996  290690  1997
# 1997  006740  1998
# 1998  317770  1999
# 1999  096610  2000
#
# [2000 rows x 2 columns]

# %%
prediction_result['종목코드'] = prediction_result['종목코드'].astype(str).str.zfill(6)
prediction_result['종목코드'] = 'A' + prediction_result['종목코드'].astype(str)

prediction_result.to_csv('2000model_hiddensize100.csv', index=False, encoding='utf-8-sig')

# %%
prediction_result
# Out:
#          종목코드    순위
# 0     A151910     1
# 1     A101140     2
# 2     A214870     3
# 3     A003560     4
# 4     A033180     5
# ...       ...   ...
# 1995  A003240  1996
# 1996  A051910  1997
# 1997  A006400  1998
# 1998  A086520  1999
# 1999  A207940  2000
#
# [2000 rows x 2 columns]
